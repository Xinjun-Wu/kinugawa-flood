# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
import plotly
# %matplotlib inline

# %%
all_data = pd.DataFrame()
for i in range(1,32,1):
    case_path = f'../save/BP032/Step_1/test/case{i} test loss.csv'
    case_data = pd.read_csv(case_path,index_col=0)
    case_data.insert(0,'CASE',f'CASE_{i}')
    all_data = all_data.append(case_data,True)

# %%
all_data
# Out:
#          CASE  EPOCH     t_1     t_2     t_3     t_4     t_5     t_6     t_7  \
# 0      CASE_1     10  0.0407  0.0530  0.0644  0.0776  0.0943  0.1140  0.1279
# 1      CASE_1     20  0.0377  0.0491  0.0596  0.0712  0.0862  0.1042  0.1169
# 2      CASE_1     30  0.0377  0.0488  0.0593  0.0708  0.0851  0.1026  0.1146
# 3      CASE_1     40  0.0362  0.0473  0.0576  0.0689  0.0829  0.1001  0.1122
# 4      CASE_1     50  0.0343  0.0442  0.0538  0.0646  0.0782  0.0947  0.1064
# ...       ...    ...     ...     ...     ...     ...     ...     ...     ...
# 6195  CASE_31   1960  0.0031  0.0032  0.0031  0.0029  0.0040  0.0057  0.0082
# 6196  CASE_31   1970  0.0031  0.0039  0.0039  0.0035  0.0045  0.0066  0.0098
# 6197  CASE_31   1980  0.0031  0.0034  0.0034  0.0031  0.0039  0.0057  0.0084
# 6198  CASE_31   1990  0.0031  0.0031  0.0029  0.0028  0.0039  0.0055  0.0076
# 6199  CASE_31   2000  0.0029  0.0035  0.0035  0.0031  0.0040  0.0061  0.0092
#
# ...

# %%
cols_label = np.array(all_data.columns)
cols_label
# Out:
# array(['CASE', 'EPOCH', 't_1', 't_2', 't_3', 't_4', 't_5', 't_6', 't_7',
#        't_8', 't_9', 't_10', 't_11', 't_12', 't_13', 't_14', 't_15',
#        't_16', 't_17', 't_18', 't_19', 't_20', 't_21', 't_22', 't_23',
#        't_24', 't_25', 't_26', 't_27', 't_28', 't_29', 't_30', 't_31',
#        't_32', 't_33', 't_34', 't_35', 't_36', 't_37', 't_38', 't_39',
#        't_40', 't_41', 't_42', 't_43', 't_44', 't_45', 't_46', 't_47',
#        't_48', 't_49', 't_50', 't_51', 't_52', 't_53', 't_54', 't_55',
#        't_56', 't_57', 't_58', 't_59', 't_60', 't_61', 't_62', 't_63',
#        't_64', 't_65', 't_66', 't_67', 't_68', 't_69', 't_70', 't_71',
#        't_72'], dtype=object)
