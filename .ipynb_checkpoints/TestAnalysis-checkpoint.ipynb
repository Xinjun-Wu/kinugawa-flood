# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
case_path = '../save/BP032/Step_1/test/case1 test loss.csv'

# %%
case_data = pd.read_csv(case_path,index_col=1)

# %%
case_data.head()
# Out:
#        Unnamed: 0     t_1     t_2     t_3     t_4     t_5     t_6     t_7  \
# EPOCH
# 10              0  0.0407  0.0530  0.0644  0.0776  0.0943  0.1140  0.1279
# 20              1  0.0377  0.0491  0.0596  0.0712  0.0862  0.1042  0.1169
# 30              2  0.0377  0.0488  0.0593  0.0708  0.0851  0.1026  0.1146
# 40              3  0.0362  0.0473  0.0576  0.0689  0.0829  0.1001  0.1122
# 50              4  0.0343  0.0442  0.0538  0.0646  0.0782  0.0947  0.1064
#
#           t_8     t_9  ...    t_63    t_64    t_65    t_66    t_67    t_68  \
# EPOCH                  ...
# 10     0.1342  0.1415  ...  0.6909  0.7015  0.7121  0.7230  0.7336  0.7440
# 20     0.1226  0.1291  ...  0.5808  0.5897  0.5986  0.6077  0.6168  0.6257
# 30     0.1195  0.1254  ...  0.6115  0.6227  0.6338  0.6451  0.6563  0.6672
# 40     0.1173  0.1233  ...  0.5831  0.5927  0.6022  0.6118  0.6212  0.6302
# 50     0.1116  0.1177  ...  0.5904  0.6005  0.6109  0.6219  0.6331  0.6446
#
# ...

# %%
case_data=case_data.drop('Unnamed: 0',axis=1)

# %%
case_data
# Out:
#           t_1     t_2     t_3     t_4     t_5     t_6     t_7     t_8     t_9  \
# EPOCH
# 10     0.0407  0.0530  0.0644  0.0776  0.0943  0.1140  0.1279  0.1342  0.1415
# 20     0.0377  0.0491  0.0596  0.0712  0.0862  0.1042  0.1169  0.1226  0.1291
# 30     0.0377  0.0488  0.0593  0.0708  0.0851  0.1026  0.1146  0.1195  0.1254
# 40     0.0362  0.0473  0.0576  0.0689  0.0829  0.1001  0.1122  0.1173  0.1233
# 50     0.0343  0.0442  0.0538  0.0646  0.0782  0.0947  0.1064  0.1116  0.1177
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1960   0.0013  0.0017  0.0021  0.0020  0.0022  0.0030  0.0042  0.0059  0.0084
# 1970   0.0013  0.0020  0.0028  0.0031  0.0033  0.0043  0.0062  0.0088  0.0124
# 1980   0.0013  0.0018  0.0024  0.0025  0.0027  0.0035  0.0050  0.0072  0.0100
# 1990   0.0013  0.0017  0.0020  0.0020  0.0022  0.0029  0.0040  0.0055  0.0079
# 2000   0.0012  0.0018  0.0025  0.0027  0.0028  0.0037  0.0054  0.0080  0.0116
#
# ...

# %%
case_data
